# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.classification.data import Urls as UrlsIC
from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset, get_transform
from utils_cv.detection.plot import (
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_counts_curves,
    plot_detections
)
from utils_cv.detection.model import (
    DetectionLearner,
    get_pretrained_fasterrcnn,
)
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend("TkAgg")

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0
# Torch is using GPU: NVIDIA GeForce MX450

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = "C:/Users/IvoRodrigues/Desktop/3rd/" #unzip_url(Urls.fridge_objects_path, exist_ok=True)
#NEG_DATA_PATH =  # unzip_url(UrlsIC.fridge_objects_negatives_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 256
SAVE_MODEL = True

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['annotations', 'images']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# #### COCO format
# A second popular annotation standard uses the COCO format introduced by the [COCO](http://cocodataset.org) challenge. Annotations in this format need to be converted first to Pascal VOC syntax in order to run this notebook. The function `coco2voc` does exactly that. See the notebook [04_coco_accuracy_vs_speed.ipynb](04_coco_accuracy_vs_speed.ipynb) for a code example.

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
print(DATA_PATH)
data = DetectionDataset(DATA_PATH, train_pct=0.75)
# Out:
# C:/Users/IvoRodrigues/Desktop/3rd/

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \
    \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 225 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x0000020D1A333048>
# Testing dataset: 75 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x0000020D19A37B08>

# %% [markdown]
# And some more detailed information, ie. the counts of ground truth boxes per class, as well as the distribution of absolute and relative widths/heights of the annotations.

# %%
data.plot_boxes_stats()

# %% [markdown]
# By default, we apply some image transformations to the training set. Lets see how the transformations look:

# %%
data.train_ds.dataset.show_im_transformations()
# Out:
# Transformations applied on C:\Users\IvoRodrigues\Desktop\3rd\images\apple_55.jpg:
# <utils_cv.detection.dataset.ColorJitterTransform object at 0x0000020D0CEDF608>
# <utils_cv.detection.references.transforms.ToTensor object at 0x0000020D0CEDF588>
# <utils_cv.detection.dataset.RandomHorizontalFlip object at 0x0000020D0CEDF648>

# %% [markdown]
# Lets visualize the annotations to make sure they look correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, we can pass in the dataset. By default, the object will set the model to torchvision's Faster R-CNN. Alternatively, we can pass in the model we want to use - we would customize the model using the `get_pretrained_fasterrcnn` function and specify the parameters we want.

# %%
detector = DetectionLearner(data, im_size=IM_SIZE)
print(f"Model: {type(detector.model)}")
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to C:\Users\IvoRodrigues/.cache\torch\checkpoints\fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:14<00:00, 11.2MB/s]
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Computation of model accuracy requires a GPU; training does not, although without GPU training is too slow for any practical purpose. To also support CPU-only machines, we skip computation steps which would otherwise throw an error.

# %%
skip_evaluation = device.type == 'cpu'

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30, skip_evaluation=skip_evaluation)
# Out:
# Epoch: [0]  [  0/113]  eta: 0:06:34  lr: 0.000050  loss: 1.5979 (1.5979)  loss_classifier: 1.1497 (1.1497)  loss_box_reg: 0.3605 (0.3605)  loss_objectness: 0.0683 (0.0683)  loss_rpn_box_reg: 0.0195 (0.0195)  time: 3.4923  data: 1.0573  max mem: 615
# Epoch: [0]  [ 30/113]  eta: 0:01:04  lr: 0.001388  loss: 0.5015 (0.6816)  loss_classifier: 0.2921 (0.4442)  loss_box_reg: 0.1819 (0.2039)  loss_objectness: 0.0129 (0.0241)  loss_rpn_box_reg: 0.0062 (0.0094)  time: 0.6441  data: 0.1573  max mem: 805
# C:\Users\IvoRodrigues\anaconda3\envs\cv\lib\site-packages\PIL\Image.py:993: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch: [0]  [ 60/113]  eta: 0:00:36  lr: 0.002725  loss: 0.2825 (0.5093)  loss_classifier: 0.1251 (0.3004)  loss_box_reg: 0.1357 (0.1819)  loss_objectness: 0.0061 (0.0188)  loss_rpn_box_reg: 0.0053 (0.0081)  time: 0.6083  data: 0.1213  max mem: 844
# Epoch: [0]  [ 90/113]  eta: 0:00:15  lr: 0.004063  loss: 0.1795 (0.4153)  loss_classifier: 0.0840 (0.2342)  loss_box_reg: 0.0963 (0.1583)  loss_objectness: 0.0033 (0.0151)  loss_rpn_box_reg: 0.0047 (0.0077)  time: 0.6405  data: 0.1566  max mem: 844
# Epoch: [0]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.1848 (0.3809)  loss_classifier: 0.0799 (0.2098)  loss_box_reg: 0.0799 (0.1488)  loss_objectness: 0.0041 (0.0144)  loss_rpn_box_reg: 0.0077 (0.0079)  time: 0.5829  data: 0.1027  max mem: 844
# Epoch: [0] Total time: 0:01:13 (0.6536 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:11  model_time: 0.2710 (0.2710)  evaluator_time: 0.0080 (0.0080)  time: 0.2920  data: 0.0099  max mem: 844
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2800 (0.2754)  evaluator_time: 0.0020 (0.0027)  time: 0.3231  data: 0.0397  max mem: 844
# Test: Total time: 0:00:12 (0.3204 s / it)
# Averaged stats: model_time: 0.2800 (0.2754)  evaluator_time: 0.0020 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.916
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.325
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.555
# Epoch: [1]  [  0/113]  eta: 0:01:18  lr: 0.005000  loss: 0.1462 (0.1462)  loss_classifier: 0.0505 (0.0505)  loss_box_reg: 0.0903 (0.0903)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 0.6991  data: 0.2300  max mem: 844
# Epoch: [1]  [ 30/113]  eta: 0:00:57  lr: 0.005000  loss: 0.1120 (0.1790)  loss_classifier: 0.0505 (0.0810)  loss_box_reg: 0.0592 (0.0828)  loss_objectness: 0.0029 (0.0080)  loss_rpn_box_reg: 0.0040 (0.0072)  time: 0.7194  data: 0.2275  max mem: 894
# Epoch: [1]  [ 60/113]  eta: 0:00:38  lr: 0.005000  loss: 0.1701 (0.1723)  loss_classifier: 0.0854 (0.0827)  loss_box_reg: 0.0691 (0.0732)  loss_objectness: 0.0043 (0.0088)  loss_rpn_box_reg: 0.0077 (0.0075)  time: 0.7486  data: 0.2549  max mem: 894
# Epoch: [1]  [ 90/113]  eta: 0:00:16  lr: 0.005000  loss: 0.1239 (0.1599)  loss_classifier: 0.0517 (0.0761)  loss_box_reg: 0.0528 (0.0683)  loss_objectness: 0.0034 (0.0080)  loss_rpn_box_reg: 0.0066 (0.0075)  time: 0.5788  data: 0.0991  max mem: 894
# Epoch: [1]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.1208 (0.1514)  loss_classifier: 0.0495 (0.0725)  loss_box_reg: 0.0327 (0.0642)  loss_objectness: 0.0011 (0.0073)  loss_rpn_box_reg: 0.0046 (0.0074)  time: 0.6119  data: 0.1427  max mem: 894
# Epoch: [1] Total time: 0:01:18 (0.6936 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2339 (0.2339)  evaluator_time: 0.0050 (0.0050)  time: 0.2545  data: 0.0130  max mem: 894
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2730 (0.2712)  evaluator_time: 0.0020 (0.0021)  time: 0.3153  data: 0.0374  max mem: 894
# Test: Total time: 0:00:11 (0.3140 s / it)
# Averaged stats: model_time: 0.2730 (0.2712)  evaluator_time: 0.0020 (0.0021)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.602
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.372
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.595
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.593
# Epoch: [2]  [  0/113]  eta: 0:02:38  lr: 0.005000  loss: 0.0689 (0.0689)  loss_classifier: 0.0334 (0.0334)  loss_box_reg: 0.0323 (0.0323)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 1.4004  data: 0.8654  max mem: 894
# Epoch: [2]  [ 30/113]  eta: 0:00:56  lr: 0.005000  loss: 0.1498 (0.1762)  loss_classifier: 0.0765 (0.1125)  loss_box_reg: 0.0397 (0.0517)  loss_objectness: 0.0027 (0.0053)  loss_rpn_box_reg: 0.0062 (0.0067)  time: 0.6677  data: 0.1796  max mem: 894
# Epoch: [2]  [ 60/113]  eta: 0:00:38  lr: 0.005000  loss: 0.1548 (0.1574)  loss_classifier: 0.0749 (0.0930)  loss_box_reg: 0.0546 (0.0524)  loss_objectness: 0.0021 (0.0049)  loss_rpn_box_reg: 0.0073 (0.0072)  time: 0.8004  data: 0.3102  max mem: 894
# Epoch: [2]  [ 90/113]  eta: 0:00:16  lr: 0.005000  loss: 0.0827 (0.1389)  loss_classifier: 0.0437 (0.0794)  loss_box_reg: 0.0363 (0.0481)  loss_objectness: 0.0010 (0.0046)  loss_rpn_box_reg: 0.0058 (0.0067)  time: 0.6170  data: 0.1407  max mem: 894
# Epoch: [2]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.0978 (0.1376)  loss_classifier: 0.0500 (0.0757)  loss_box_reg: 0.0292 (0.0502)  loss_objectness: 0.0017 (0.0050)  loss_rpn_box_reg: 0.0040 (0.0068)  time: 0.6046  data: 0.1341  max mem: 894
# Epoch: [2] Total time: 0:01:16 (0.6781 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:08  model_time: 0.2131 (0.2131)  evaluator_time: 0.0040 (0.0040)  time: 0.2350  data: 0.0140  max mem: 894
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2711 (0.2712)  evaluator_time: 0.0019 (0.0018)  time: 0.3167  data: 0.0365  max mem: 894
# Test: Total time: 0:00:11 (0.3122 s / it)
# Averaged stats: model_time: 0.2711 (0.2712)  evaluator_time: 0.0019 (0.0018)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.532
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.940
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.563
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.602
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.391
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.597
# Epoch: [3]  [  0/113]  eta: 0:00:55  lr: 0.005000  loss: 0.0516 (0.0516)  loss_classifier: 0.0228 (0.0228)  loss_box_reg: 0.0265 (0.0265)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0013 (0.0013)  time: 0.4888  data: 0.0230  max mem: 894
# Epoch: [3]  [ 30/113]  eta: 0:00:53  lr: 0.005000  loss: 0.0647 (0.1149)  loss_classifier: 0.0399 (0.0576)  loss_box_reg: 0.0238 (0.0474)  loss_objectness: 0.0013 (0.0030)  loss_rpn_box_reg: 0.0052 (0.0069)  time: 0.6285  data: 0.1533  max mem: 907
# Epoch: [3]  [ 60/113]  eta: 0:00:32  lr: 0.005000  loss: 0.1116 (0.1182)  loss_classifier: 0.0541 (0.0573)  loss_box_reg: 0.0586 (0.0511)  loss_objectness: 0.0011 (0.0032)  loss_rpn_box_reg: 0.0051 (0.0065)  time: 0.5703  data: 0.1004  max mem: 907
# Epoch: [3]  [ 90/113]  eta: 0:00:14  lr: 0.005000  loss: 0.0688 (0.1126)  loss_classifier: 0.0344 (0.0550)  loss_box_reg: 0.0290 (0.0479)  loss_objectness: 0.0013 (0.0033)  loss_rpn_box_reg: 0.0049 (0.0065)  time: 0.6316  data: 0.1609  max mem: 907
# Epoch: [3]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.0673 (0.1044)  loss_classifier: 0.0339 (0.0518)  loss_box_reg: 0.0204 (0.0435)  loss_objectness: 0.0007 (0.0030)  loss_rpn_box_reg: 0.0039 (0.0060)  time: 0.5656  data: 0.1058  max mem: 907
# Epoch: [3] Total time: 0:01:08 (0.6078 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2329 (0.2329)  evaluator_time: 0.0040 (0.0040)  time: 0.2490  data: 0.0080  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2689 (0.2631)  evaluator_time: 0.0020 (0.0019)  time: 0.3143  data: 0.0400  max mem: 907
# Test: Total time: 0:00:11 (0.3070 s / it)
# Averaged stats: model_time: 0.2689 (0.2631)  evaluator_time: 0.0020 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.598
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.948
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.717
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.761
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.653
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.653
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.650
# Epoch: [4]  [  0/113]  eta: 0:00:56  lr: 0.005000  loss: 0.0265 (0.0265)  loss_classifier: 0.0147 (0.0147)  loss_box_reg: 0.0100 (0.0100)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 0.4991  data: 0.0280  max mem: 907
# Epoch: [4]  [ 30/113]  eta: 0:00:52  lr: 0.005000  loss: 0.0776 (0.0957)  loss_classifier: 0.0392 (0.0472)  loss_box_reg: 0.0297 (0.0399)  loss_objectness: 0.0005 (0.0028)  loss_rpn_box_reg: 0.0055 (0.0058)  time: 0.6421  data: 0.1638  max mem: 907
# Epoch: [4]  [ 60/113]  eta: 0:00:32  lr: 0.005000  loss: 0.0679 (0.0877)  loss_classifier: 0.0399 (0.0439)  loss_box_reg: 0.0226 (0.0362)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0043 (0.0055)  time: 0.6045  data: 0.1353  max mem: 907
# Epoch: [4]  [ 90/113]  eta: 0:00:14  lr: 0.005000  loss: 0.0736 (0.0869)  loss_classifier: 0.0394 (0.0441)  loss_box_reg: 0.0333 (0.0354)  loss_objectness: 0.0005 (0.0018)  loss_rpn_box_reg: 0.0043 (0.0057)  time: 0.6449  data: 0.1738  max mem: 907
# Epoch: [4]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.0741 (0.0855)  loss_classifier: 0.0378 (0.0436)  loss_box_reg: 0.0147 (0.0348)  loss_objectness: 0.0004 (0.0016)  loss_rpn_box_reg: 0.0022 (0.0055)  time: 0.5718  data: 0.1159  max mem: 907
# Epoch: [4] Total time: 0:01:08 (0.6090 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2321 (0.2321)  evaluator_time: 0.0030 (0.0030)  time: 0.2481  data: 0.0100  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2673 (0.2606)  evaluator_time: 0.0020 (0.0016)  time: 0.3043  data: 0.0337  max mem: 907
# Test: Total time: 0:00:11 (0.2999 s / it)
# Averaged stats: model_time: 0.2673 (0.2606)  evaluator_time: 0.0020 (0.0016)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.606
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.938
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.737
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.679
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.606
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.833
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.662
# Epoch: [5]  [  0/113]  eta: 0:00:58  lr: 0.005000  loss: 0.0145 (0.0145)  loss_classifier: 0.0069 (0.0069)  loss_box_reg: 0.0053 (0.0053)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.5196  data: 0.0465  max mem: 907
# Epoch: [5]  [ 30/113]  eta: 0:00:49  lr: 0.005000  loss: 0.0595 (0.0713)  loss_classifier: 0.0254 (0.0425)  loss_box_reg: 0.0118 (0.0225)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0029 (0.0048)  time: 0.5784  data: 0.1089  max mem: 907
# Epoch: [5]  [ 60/113]  eta: 0:00:31  lr: 0.005000  loss: 0.0510 (0.0719)  loss_classifier: 0.0314 (0.0427)  loss_box_reg: 0.0170 (0.0234)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 0.5555  data: 0.0869  max mem: 907
# Epoch: [5]  [ 90/113]  eta: 0:00:13  lr: 0.005000  loss: 0.0799 (0.0800)  loss_classifier: 0.0471 (0.0464)  loss_box_reg: 0.0285 (0.0272)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0048 (0.0051)  time: 0.5974  data: 0.1225  max mem: 907
# Epoch: [5]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.0770 (0.0824)  loss_classifier: 0.0400 (0.0468)  loss_box_reg: 0.0274 (0.0287)  loss_objectness: 0.0004 (0.0014)  loss_rpn_box_reg: 0.0058 (0.0055)  time: 0.6274  data: 0.1652  max mem: 907
# Epoch: [5] Total time: 0:01:07 (0.6016 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2361 (0.2361)  evaluator_time: 0.0020 (0.0020)  time: 0.2522  data: 0.0100  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2642 (0.2585)  evaluator_time: 0.0010 (0.0014)  time: 0.2983  data: 0.0328  max mem: 907
# Test: Total time: 0:00:11 (0.2958 s / it)
# Averaged stats: model_time: 0.2642 (0.2585)  evaluator_time: 0.0010 (0.0014)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.619
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.940
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.767
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.618
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.671
# Epoch: [6]  [  0/113]  eta: 0:01:11  lr: 0.005000  loss: 0.0168 (0.0168)  loss_classifier: 0.0080 (0.0080)  loss_box_reg: 0.0067 (0.0067)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.6309  data: 0.1487  max mem: 907
# Epoch: [6]  [ 30/113]  eta: 0:00:48  lr: 0.005000  loss: 0.0498 (0.0625)  loss_classifier: 0.0299 (0.0346)  loss_box_reg: 0.0147 (0.0216)  loss_objectness: 0.0005 (0.0009)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 0.5885  data: 0.1210  max mem: 907
# Epoch: [6]  [ 60/113]  eta: 0:00:31  lr: 0.005000  loss: 0.0451 (0.0561)  loss_classifier: 0.0224 (0.0300)  loss_box_reg: 0.0137 (0.0207)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0026 (0.0046)  time: 0.5426  data: 0.0727  max mem: 907
# Epoch: [6]  [ 90/113]  eta: 0:00:13  lr: 0.005000  loss: 0.0488 (0.0596)  loss_classifier: 0.0249 (0.0316)  loss_box_reg: 0.0209 (0.0226)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0042 (0.0047)  time: 0.6423  data: 0.1760  max mem: 907
# Epoch: [6]  [112/113]  eta: 0:00:00  lr: 0.005000  loss: 0.0506 (0.0682)  loss_classifier: 0.0317 (0.0353)  loss_box_reg: 0.0150 (0.0267)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0049 (0.0053)  time: 0.6200  data: 0.1608  max mem: 907
# Epoch: [6] Total time: 0:01:08 (0.6051 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2360 (0.2360)  evaluator_time: 0.0030 (0.0030)  time: 0.2550  data: 0.0121  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2660 (0.2653)  evaluator_time: 0.0010 (0.0015)  time: 0.3099  data: 0.0370  max mem: 907
# Test: Total time: 0:00:11 (0.3093 s / it)
# Averaged stats: model_time: 0.2660 (0.2653)  evaluator_time: 0.0010 (0.0015)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.643
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.954
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.717
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.453
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.698
# Epoch: [7]  [  0/113]  eta: 0:00:58  lr: 0.000500  loss: 0.1189 (0.1189)  loss_classifier: 0.0525 (0.0525)  loss_box_reg: 0.0563 (0.0563)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0094 (0.0094)  time: 0.5165  data: 0.0564  max mem: 907
# Epoch: [7]  [ 30/113]  eta: 0:00:52  lr: 0.000500  loss: 0.0468 (0.0555)  loss_classifier: 0.0265 (0.0296)  loss_box_reg: 0.0138 (0.0211)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0039 (0.0042)  time: 0.5984  data: 0.1228  max mem: 907
# Epoch: [7]  [ 60/113]  eta: 0:00:32  lr: 0.000500  loss: 0.0434 (0.0559)  loss_classifier: 0.0303 (0.0294)  loss_box_reg: 0.0113 (0.0214)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 0.5815  data: 0.1157  max mem: 907
# Epoch: [7]  [ 90/113]  eta: 0:00:14  lr: 0.000500  loss: 0.0220 (0.0545)  loss_classifier: 0.0166 (0.0292)  loss_box_reg: 0.0058 (0.0205)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0017 (0.0042)  time: 0.6220  data: 0.1526  max mem: 907
# Epoch: [7]  [112/113]  eta: 0:00:00  lr: 0.000500  loss: 0.0354 (0.0547)  loss_classifier: 0.0208 (0.0294)  loss_box_reg: 0.0095 (0.0205)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0031 (0.0042)  time: 0.5796  data: 0.1253  max mem: 907
# Epoch: [7] Total time: 0:01:09 (0.6117 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2279 (0.2279)  evaluator_time: 0.0030 (0.0030)  time: 0.2428  data: 0.0089  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2625 (0.2565)  evaluator_time: 0.0011 (0.0013)  time: 0.2950  data: 0.0302  max mem: 907
# Test: Total time: 0:00:11 (0.2916 s / it)
# Averaged stats: model_time: 0.2625 (0.2565)  evaluator_time: 0.0011 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.714
# Epoch: [8]  [  0/113]  eta: 0:01:04  lr: 0.000500  loss: 0.0143 (0.0143)  loss_classifier: 0.0074 (0.0074)  loss_box_reg: 0.0065 (0.0065)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 0.5680  data: 0.0979  max mem: 907
# Epoch: [8]  [ 30/113]  eta: 0:00:47  lr: 0.000500  loss: 0.0522 (0.0577)  loss_classifier: 0.0290 (0.0312)  loss_box_reg: 0.0137 (0.0215)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0028 (0.0043)  time: 0.5897  data: 0.1186  max mem: 907
# Epoch: [8]  [ 60/113]  eta: 0:00:31  lr: 0.000500  loss: 0.0292 (0.0548)  loss_classifier: 0.0208 (0.0296)  loss_box_reg: 0.0082 (0.0205)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0021 (0.0040)  time: 0.6177  data: 0.1506  max mem: 907
# Epoch: [8]  [ 90/113]  eta: 0:00:13  lr: 0.000500  loss: 0.0277 (0.0512)  loss_classifier: 0.0176 (0.0275)  loss_box_reg: 0.0073 (0.0191)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0034 (0.0039)  time: 0.5769  data: 0.1109  max mem: 907
# Epoch: [8]  [112/113]  eta: 0:00:00  lr: 0.000500  loss: 0.0380 (0.0519)  loss_classifier: 0.0231 (0.0278)  loss_box_reg: 0.0130 (0.0194)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0024 (0.0039)  time: 0.6199  data: 0.1558  max mem: 907
# Epoch: [8] Total time: 0:01:06 (0.5877 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2369 (0.2369)  evaluator_time: 0.0020 (0.0020)  time: 0.2512  data: 0.0092  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2594 (0.2570)  evaluator_time: 0.0010 (0.0013)  time: 0.2964  data: 0.0307  max mem: 907
# Test: Total time: 0:00:11 (0.2927 s / it)
# Averaged stats: model_time: 0.2594 (0.2570)  evaluator_time: 0.0010 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.942
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.768
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.714
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.714
# Epoch: [9]  [  0/113]  eta: 0:01:00  lr: 0.000500  loss: 0.0832 (0.0832)  loss_classifier: 0.0475 (0.0475)  loss_box_reg: 0.0309 (0.0309)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0047 (0.0047)  time: 0.5352  data: 0.0608  max mem: 907
# Epoch: [9]  [ 30/113]  eta: 0:00:49  lr: 0.000500  loss: 0.0399 (0.0466)  loss_classifier: 0.0221 (0.0270)  loss_box_reg: 0.0131 (0.0154)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0028 (0.0035)  time: 0.5857  data: 0.1186  max mem: 907
# Epoch: [9]  [ 60/113]  eta: 0:00:32  lr: 0.000500  loss: 0.0429 (0.0527)  loss_classifier: 0.0249 (0.0287)  loss_box_reg: 0.0176 (0.0190)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0041 (0.0042)  time: 0.6140  data: 0.1501  max mem: 907
# Epoch: [9]  [ 90/113]  eta: 0:00:13  lr: 0.000500  loss: 0.0410 (0.0505)  loss_classifier: 0.0255 (0.0280)  loss_box_reg: 0.0099 (0.0177)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 0.5706  data: 0.1045  max mem: 907
# Epoch: [9]  [112/113]  eta: 0:00:00  lr: 0.000500  loss: 0.0291 (0.0487)  loss_classifier: 0.0187 (0.0271)  loss_box_reg: 0.0087 (0.0171)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0020 (0.0038)  time: 0.5528  data: 0.0966  max mem: 907
# Epoch: [9] Total time: 0:01:06 (0.5891 s / it)
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2283 (0.2283)  evaluator_time: 0.0021 (0.0021)  time: 0.2424  data: 0.0090  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2621 (0.2576)  evaluator_time: 0.0010 (0.0013)  time: 0.2966  data: 0.0311  max mem: 907
# Test: Total time: 0:00:11 (0.2932 s / it)
# Averaged stats: model_time: 0.2621 (0.2576)  evaluator_time: 0.0010 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.949
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
if not skip_evaluation:
    detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
if not skip_evaluation:
    e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/38]  eta: 0:00:09  model_time: 0.2334 (0.2334)  evaluator_time: 0.0020 (0.0020)  time: 0.2625  data: 0.0090  max mem: 907
# Test:  [37/38]  eta: 0:00:00  model_time: 0.2635 (0.2608)  evaluator_time: 0.0010 (0.0012)  time: 0.3033  data: 0.0339  max mem: 907
# Test: Total time: 0:00:11 (0.2998 s / it)
# Averaged stats: model_time: 0.2635 (0.2608)  evaluator_time: 0.0010 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.949
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.717
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
if not skip_evaluation:
    plot_pr_curves(e)

# %% [markdown]
# Precision-Recall curves can be hard to interpret, and hence we also provide counts how many (left) images have at least one wrong detection / missed ground truth; and (right) the total number of wrong detections / missed ground truths summed over all images. These counts are shown for different detection score thresholds, ie. effectly discarding detections with confidence score lower than a given thresholds.
#
# As can be seen, the model performs well on the test dataset for thresholds between 0.5 and 0.9, but especially at a threshold of 0.5 over-fires on the negative images (images which do not contain any of the objects) since similar images were not included in the training set. This information is especially valuable when deciding on a precision-recall operating point. To avoid over-firing, one can either add more images to the training set directly or via hard-negative mining as explained in the [12_hard_negative_sampling.ipynb](12_hard_negative_sampling.ipynb) notebook.

# %%
# Run detector on the test images. Set threshold to 0 to keep all low confidence detections.
print(f"Running detector on {len(data.test_ds)} test images...")
detections = detector.predict_dl(data.test_dl, threshold=0)
"""
# Run detector on the negative images
if NEG_DATA_PATH is None or NEG_DATA_PATH == "":
    detections_neg = None
else:
    neg_data = DetectionDataset(
        NEG_DATA_PATH,
        train_pct=1.0,  # , batch_size=BATCH_SIZE,
        im_dir="",
        allow_negatives=True,
        train_transforms=get_transform(train=False),
    )
    print(f"Running detector on {len(neg_data.train_ds)} negative images...")
    detections_neg = detector.predict_dl(neg_data.train_dl, threshold=0)
"""
# Count and plot number of wrong/missing detections
plot_counts_curves(detections, data.test_ds)
# Out:
# Running detector on 75 test images...

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)
# Out:
# C:\Users\IvoRodrigues\anaconda3\envs\cv\lib\site-packages\PIL\Image.py:993: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 281,
#   'det_bboxes': [{Bbox object: [left=289, top=9, right=562, bottom=293] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_78.jpg} | score: 0.9985650181770325],
#   'im_path': 'C:\\Users\\IvoRodrigues\\Desktop\\3rd\\images\\orange_78.jpg'},
#  {'idx': 210,
#   'det_bboxes': [{Bbox object: [left=85, top=120, right=237, bottom=274] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_1.jpg} | score: 0.9984362721443176,
#    {Bbox object: [left=245, top=123, right=385, bottom=270] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_1.jpg} | score: 0.998316764831543,
#    {Bbox object: [left=178, top=27, right=314, bottom=181] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_1.jpg} | score: 0.99739009141922,
#    {Bbox object: [left=424, top=108, right=564, bottom=257] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_1.jpg} | score: 0.9973770380020142,
#    {Bbox object: [left=79, top=52, right=207, bottom=163] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_1.jpg} | score: 0.9925746917724609,
#    {Bbox object: [left=429, top=56, right=578, bottom=167] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_1.jpg} | score: 0.9837350845336914],
#   'im_path': 'C:\\Users\\IvoRodrigues\\Desktop\\3rd\\images\\orange_1.jpg'},
#  {'idx': 77,
#   'det_bboxes': [{Bbox object: [left=150, top=107, right=461, bottom=439] | <apple> | label:1 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\apple_80.jpg} | score: 0.9989180564880371],
#   'im_path': 'C:\\Users\\IvoRodrigues\\Desktop\\3rd\\images\\apple_80.jpg'},
#  {'idx': 277,
#   'det_bboxes': [{Bbox object: [left=11, top=12, right=272, bottom=274] | <orange> | label:2 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\orange_74.jpg} | score: 0.9909290671348572],
#   'im_path': 'C:\\Users\\IvoRodrigues\\Desktop\\3rd\\images\\orange_74.jpg'},
#  {'idx': 80,
#   'det_bboxes': [{Bbox object: [left=0, top=0, right=791, bottom=738] | <apple> | label:1 | path:C:\Users\IvoRodrigues\Desktop\3rd\images\apple_83.jpg} | score: 0.9984363913536072],
#   'im_path': 'C:\\Users\\IvoRodrigues\\Desktop\\3rd\\images\\apple_83.jpg'}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(
    f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}"
)
# Out:
# Number of detections: 75
# Number of test images: 75

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def _grid_helper():
    for detection in detections:
        yield detection, data, None, None
plot_grid(plot_detections, _grid_helper(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# WindowsPath('C:/Users/IvoRodrigues/Desktop/3rd/images/orange_12.jpg')

# %% [markdown]
# We can use the inference function, which accepts either an image or a path to an image as input. Note that we set `threshold=0.5` to suppress detections with low confidence.

# %%
detections = detector.predict(new_im_path, threshold=0.5)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_detections(detections)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x336 at 0x20D1A6DF548>

# %% [markdown]
# ## Save the model
# The final step is to save the model to disk. We'll do this since the deployment notebook will deploy this model.

# %%
if SAVE_MODEL:
    detector.save("fruit_detection")
# Out:
# Model is saved to C:\Users\IvoRodrigues\Desktop\3rd\models\fruit_detection

# %%
# Preserve some of the notebook outputs
sb.glue("skip_evaluation", skip_evaluation)
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

# %%
print(detector.ap)
# Out:
# [{'bbox': 0.4449679751909602}, {'bbox': 0.5227989821411873}, {'bbox': 0.5316132235098119}, {'bbox': 0.5978524396643679}, {'bbox': 0.6058469582518032}, {'bbox': 0.6188964007576467}, {'bbox': 0.6431527553040748}, {'bbox': 0.6688501859512183}, {'bbox': 0.6662611826957124}, {'bbox': 0.6740413400240349}]
